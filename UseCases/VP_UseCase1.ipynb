# %%
{"nodes":[{"id":"0","type":"Flow Control.Execute Start","position":{"x":-234.3669119259941,"y":407.3864609630855},"outputs":{"execOut":{"dataType":"exec"}},"title":"Execute Start"},{"id":"1","type":"imageio.read_image","position":{"x":-118.28906769985977,"y":408.01318501918036},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"path":{"title":"path","value":"raw.jpg","dataType":"string"},"mode":{"title":"mode","value":" ImageReadMode.GRAY","dataType":"imageio.ImageReadMode"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"read_image"},{"id":"2","type":"image visualization.show_image","position":{"x":162.97990741217393,"y":408.77031549789973},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":false,"channelOrder":"channelLast","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"title":{"title":"title","value":"raw","dataType":"string"},"cmap":{"title":"cmap","value":"gray","dataType":"string"},"figSize":{"title":"figSize","value":"(2, 5)","dataType":"tuple"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"}},"title":"show_image"},{"id":"3","type":"Flow Control.Sequence","position":{"x":446.826370005183,"y":409.47813541037146},"inputs":{"execIn":{"title":"execIn","dataType":"exec"}},"outputs":{"execOut0":{"title":"Then 0","dataType":"exec"},"execOut1":{"title":"Then 1","dataType":"exec"}},"title":"Sequence"},{"id":"10","type":"numpy.max","position":{"x":2687.237391583377,"y":659.1863764510701},"inputs":{"ndarray":{"title":"ndarray","dataType":"numpy.ndarray"}},"outputs":{"max":{"title":"max ","dataType":"integer"}},"title":"max"},{"id":"25","type":"numpy.image To ndarray","position":{"x":2234.484755110023,"y":556.6913365091934},"inputs":{"image":{"title":"image","dataType":"image"}},"outputs":{"string":{"title":"ndarray","dataType":"numpy.ndarray"}},"title":"->"},{"id":"26","type":"numpy.max","position":{"x":2687.237391583377,"y":587.2399801190451},"inputs":{"ndarray":{"title":"ndarray","dataType":"numpy.ndarray"}},"outputs":{"max":{"title":"max ","dataType":"integer"}},"title":"max"},{"id":"27","type":"Log.Print String","position":{"x":2722.1779103052,"y":649.2218327663898},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"input":{"title":"In String","value":"Hello","dataType":"string"}},"outputs":{"execOut":{"dataType":"exec"}},"title":"Print String"},{"id":"28","type":"Scikiimage./","position":{"x":2572.0047874101106,"y":621.3086659415117},"inputs":{"int1":{"title":"x1","value":0,"dataType":"anyDataType"},"int2":{"title":"x2","value":1,"dataType":"anyDataType"}},"outputs":{"quotient":{"dataType":"anyDataType"}},"title":"/"},{"id":"4","type":"numpy.binarize","position":{"x":1543.1494259581218,"y":628.7198628737168},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"threshold":{"title":"threshold","value":125,"dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"binarized":{"dataType":"image"}},"title":"binarize"},{"id":"8","type":"image visualization.show_image","position":{"x":2542.4463414510956,"y":901.6533695077458},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":false,"channelOrder":"channelLast","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"title":{"title":"title","dataType":"string"},"cmap":{"title":"cmap","dataType":"string"},"figSize":{"title":"figSize","dataType":"tuple"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"}},"title":"show_image"},{"id":"9","type":"Scikiimage.measure.label","position":{"x":2805.4463414510956,"y":890.6533695077458},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"background":{"title":"background","dataType":"anyDataType"},"return_num":{"title":"return_num","dataType":"anyDataType"},"connectivity":{"title":"connectivity","dataType":"anyDataType"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"labels":{"title":"labels","dataType":"numpy.ndarray"},"connectivity":{"title":"connectivity","dataType":"integer"}},"title":"label"},{"id":"5","type":"Scikiimage.filter.mean","position":{"x":1924.4463414510956,"y":875.6575330022262},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":true,"channelOrder":"channelFirst","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"footprint":{"title":"footprint","value":"None","dataType":"numpy.ndarray"},"out":{"title":"out","value":"None","dataType":"numpy.ndarray"},"mask":{"title":"mask","value":"None","dataType":"numpy.ndarray"},"shift_x":{"title":"shift_x","dataType":"integer"},"shift_y":{"title":"shift_y","dataType":"integer"},"shift_z":{"title":"shift_z","dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"mean"},{"id":"6","type":"Scikiimage.morphology.disk","position":{"x":1593.4463414510956,"y":886.6575330022262},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"radius":{"title":"radius","value":3,"dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"footprint":{"title":"footprint","dataType":"numpy.ndarray"}},"title":"disk"},{"id":"7","type":"numpy.binarize","position":{"x":2211.4463414510956,"y":811},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"threshold":{"title":"threshold","value":20,"dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"binarized":{"dataType":"image"}},"title":"binarize"},{"id":"11","type":"Scikiimage.segmentation.threshold_multiotsu","position":{"x":751.4797572026096,"y":373.06863835755803},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"classes":{"title":"classes","dataType":"integer"},"nbins":{"title":"nbins","dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"thresh":{"title":"thresh","dataType":"list"}},"title":"threshold_multiotsu"},{"id":"12","type":"numpy.binarize","position":{"x":722,"y":173},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"threshold":{"title":"threshold","value":128,"dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"binarized":{"dataType":"image"}},"title":"binarize"},{"id":"13","type":"List.Get","position":{"x":347,"y":183},"inputs":{"input":{"title":"list","value":"[]","dataType":"list"},"index":{"title":"index","dataType":"integer"}},"outputs":{"element":{"title":"element","dataType":"anyDataType"}},"dataType":"anyDataType","title":"Get"},{"id":"14","type":"Scikiimage.feature.peak_local_max","position":{"x":1386.2377451626662,"y":570.9302367430242},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"ndarray":{"title":"ndarray","dataType":"numpy.ndarray"},"min_distance":{"title":"min_distance","value":"7","dataType":"anyDataType"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"peaks":{"title":"peaks","dataType":"numpy.ndarray"}},"title":"peak_local_max"},{"id":"15","type":"Scikiimage.measure.distance_transform_edt","position":{"x":864.7596843426343,"y":415.06590751492627},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"sampling":{"title":"sampling","dataType":"anyDataType"},"return_distances":{"title":"return_distances","dataType":"boolean"},"return_indices":{"title":"return_indices","dataType":"boolean"},"distances":{"title":"distances","dataType":"anyDataType"},"indices":{"title":"indices","dataType":"anyDataType"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"labels":{"title":"labels","dataType":"numpy.ndarray"},"connectivity":{"title":"connectivity","dataType":"integer"}},"title":"distance_transform_edt"},{"id":"16","type":"Scikiimage.image.create_mask","position":{"x":1800.865614475448,"y":458.6734143313469},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"coordinates":{"title":"coordinates","dataType":"numpy.ndarray"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"create_mask"},{"id":"17","type":"numpy.transpose","position":{"x":1539.950890675643,"y":443.27005629645424},"inputs":{"ndarray":{"title":"ndarray","dataType":"numpy.ndarray"}},"outputs":{"transpose":{"title":"transpose","dataType":"numpy.ndarray"}},"title":"transpose"},{"id":"18","type":"Scikiimage.measure.label","position":{"x":2016.142097008652,"y":367.51943629958225},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"background":{"title":"background","dataType":"anyDataType"},"return_num":{"title":"return_num","dataType":"anyDataType"},"connectivity":{"title":"connectivity","dataType":"anyDataType"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"labels":{"title":"labels","dataType":"numpy.ndarray"},"connectivity":{"title":"connectivity","dataType":"integer"}},"title":"label"},{"id":"19","type":"Scikiimage.segmentation.watershed","position":{"x":2402.935377732424,"y":178.5675383139632},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"markers":{"title":"markers","value":"None","dataType":"numpy.ndarray"},"mask":{"title":"mask","value":"None","dataType":"numpy.ndarray"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"watershed"},{"id":"20","type":"numpy.ndarray * float","position":{"x":1355.4547464176924,"y":193.89278461983665},"inputs":{"input1":{"title":"ndarray","dataType":"numpy.ndarray"},"input2":{"title":"float","value":-1,"dataType":"float"}},"outputs":{"string":{"title":"ndarray","dataType":"numpy.ndarray"}},"title":"*"},{"id":"21","type":"numpy.ndarray To image","position":{"x":2225.5,"y":52},"inputs":{"ndarray":{"title":"ndarray","dataType":"numpy.ndarray"}},"outputs":{"image":{"title":"image","dataType":"image"}},"title":"->"},{"id":"22","type":"numpy.image To ndarray","position":{"x":1916.0000000000002,"y":163},"inputs":{"image":{"title":"image","dataType":"image"}},"outputs":{"string":{"title":"ndarray","dataType":"numpy.ndarray"}},"title":"->"},{"id":"23","type":"image visualization.show_image","position":{"x":2649.9430892165224,"y":374.19772254477874},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":false,"channelOrder":"channelLast","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"title":{"title":"title","dataType":"string"},"cmap":{"title":"cmap","dataType":"string"},"figSize":{"title":"figSize","dataType":"tuple"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"}},"title":"show_image"},{"id":"24","type":"Scikiimage.label2rgb","position":{"x":2567.040022617887,"y":304.4108680577555},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"label":{"title":"label","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"image":{"title":"image","dataType":"image"},"alpha":{"title":"alpha","dataType":"float"},"bg_color":{"title":"bg_color","dataType":"string"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"label2rgb"}],"edges":[{"id":"reactflow__edge-0execOut-1execIn","output":"0","input":"1","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-1execOut-2execIn","output":"1","input":"2","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-1image-2image","output":"1","input":"2","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-2execOut-3execIn","output":"2","input":"3","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-1image-4image","output":"1","input":"4","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-4binarized-5image","output":"4","input":"5","outputHandle":"binarized","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-6execOut-5execIn","output":"6","input":"5","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-6footprint-5footprint","output":"6","input":"5","outputHandle":"footprint","inputHandle":"footprint","dataType":"numpy.ndarray"},{"id":"reactflow__edge-5execOut-7execIn","output":"5","input":"7","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-5image-7image","output":"5","input":"7","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-7binarized-8image","output":"7","input":"8","outputHandle":"binarized","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-7execOut-8execIn","output":"7","input":"8","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-8execOut-9execIn","output":"8","input":"9","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-7binarized-9image","output":"7","input":"9","outputHandle":"binarized","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-9labels-10ndarray","output":"9","input":"10","outputHandle":"labels","inputHandle":"ndarray","dataType":"numpy.ndarray"},{"id":"reactflow__edge-3execOut1-11execIn","output":"3","input":"11","outputHandle":"execOut1","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-3execOut0-4execIn","output":"3","input":"4","outputHandle":"execOut0","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-4execOut-6execIn","output":"4","input":"6","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-1image-11image","output":"1","input":"11","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-11execOut-12execIn","output":"11","input":"12","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-11thresh-13input","output":"11","input":"13","outputHandle":"thresh","inputHandle":"input","dataType":"list"},{"id":"reactflow__edge-13element-12threshold","output":"13","input":"12","outputHandle":"element","inputHandle":"threshold","dataType":"integer"},{"id":"reactflow__edge-1image-12image","output":"1","input":"12","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-12execOut-15execIn","output":"12","input":"15","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-12binarized-15image","output":"12","input":"15","outputHandle":"binarized","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-15execOut-14execIn","output":"15","input":"14","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-15labels-14ndarray","output":"15","input":"14","outputHandle":"labels","inputHandle":"ndarray","dataType":"numpy.ndarray"},{"id":"reactflow__edge-14execOut-16execIn","output":"14","input":"16","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-14peaks-17ndarray","output":"14","input":"17","outputHandle":"peaks","inputHandle":"ndarray","dataType":"numpy.ndarray"},{"id":"reactflow__edge-17transpose-16coordinates","output":"17","input":"16","outputHandle":"transpose","inputHandle":"coordinates","dataType":"numpy.ndarray"},{"id":"reactflow__edge-16execOut-18execIn","output":"16","input":"18","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-16image-18image","output":"16","input":"18","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-18execOut-19execIn","output":"18","input":"19","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-15labels-20input1","output":"15","input":"20","outputHandle":"labels","inputHandle":"input1","dataType":"numpy.ndarray"},{"id":"reactflow__edge-20string-21ndarray","output":"20","input":"21","outputHandle":"string","inputHandle":"ndarray","dataType":"numpy.ndarray"},{"id":"reactflow__edge-21image-19image","output":"21","input":"19","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-22string-19mask","output":"22","input":"19","outputHandle":"string","inputHandle":"mask","dataType":"numpy.ndarray"},{"id":"reactflow__edge-12binarized-22image","output":"12","input":"22","outputHandle":"binarized","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-18labels-19markers","output":"18","input":"19","outputHandle":"labels","inputHandle":"markers","dataType":"numpy.ndarray"},{"id":"reactflow__edge-19execOut-24execIn","output":"19","input":"24","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-19image-24label","output":"19","input":"24","outputHandle":"image","inputHandle":"label","dataType":"image"},{"id":"reactflow__edge-24execOut-23execIn","output":"24","input":"23","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-24image-23image","output":"24","input":"23","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-19image-25image","output":"19","input":"25","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-25string-26ndarray","output":"25","input":"26","outputHandle":"string","inputHandle":"ndarray","dataType":"numpy.ndarray"},{"id":"reactflow__edge-23execOut-27execIn","output":"23","input":"27","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-10max-28int1","output":"10","input":"28","outputHandle":"max","inputHandle":"int1","dataType":"anyDataType"},{"id":"reactflow__edge-26max-28int2","output":"26","input":"28","outputHandle":"max","inputHandle":"int2","dataType":"anyDataType"},{"id":"reactflow__edge-28quotient-27input","output":"28","input":"27","outputHandle":"quotient","inputHandle":"input","dataType":"string"}]}

# %%
{"nodes":[{"id":"1","type":"imageio.read_image","position":{"x":46.13605506566233,"y":314.11744744714133},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"path":{"title":"path","value":"raw.jpg","dataType":"string"},"mode":{"title":"mode","value":" ImageReadMode.GRAY","dataType":"imageio.ImageReadMode"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"read_image"},{"id":"2","type":"image visualization.show_image","position":{"x":330.56954996480715,"y":314.98295276057684},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":false,"channelOrder":"channelLast","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"title":{"title":"title","value":"raw","dataType":"string"},"cmap":{"title":"cmap","value":"gray","dataType":"string"},"figSize":{"title":"figSize","value":"(2, 5)","dataType":"tuple"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"}},"title":"show_image"},{"id":"3","type":"Flow Control.Sequence","position":{"x":597.500115262873,"y":314.8714644963135},"inputs":{"execIn":{"title":"execIn","dataType":"exec"}},"outputs":{"execOut0":{"title":"Then 0","dataType":"exec"},"execOut1":{"title":"Then 1","dataType":"exec"}},"title":"Sequence"},{"id":"10","type":"numpy.max","position":{"x":3089.4551501568735,"y":395.18756476357726},"inputs":{"ndarray":{"title":"ndarray","dataType":"numpy.ndarray"}},"outputs":{"max":{"title":"max ","dataType":"integer"}},"title":"max"},{"id":"25","type":"numpy.image To ndarray","position":{"x":2817.976272372468,"y":566.462786816251},"inputs":{"image":{"title":"image","dataType":"image"}},"outputs":{"string":{"title":"ndarray","dataType":"numpy.ndarray"}},"title":"->"},{"id":"26","type":"numpy.max","position":{"x":3091.70737536402,"y":447.47550670333544},"inputs":{"ndarray":{"title":"ndarray","dataType":"numpy.ndarray"}},"outputs":{"max":{"title":"max ","dataType":"integer"}},"title":"max"},{"id":"27","type":"Log.Print String","position":{"x":3439.0059963462463,"y":667.7498547413409},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"input":{"title":"In String","value":"Hello","dataType":"string"}},"outputs":{"execOut":{"dataType":"exec"}},"title":"Print String"},{"id":"28","type":"Scikiimage./","position":{"x":3260.893819707839,"y":400.8751078963702},"inputs":{"int1":{"title":"x1","value":0,"dataType":"anyDataType"},"int2":{"title":"x2","value":1,"dataType":"anyDataType"}},"outputs":{"quotient":{"dataType":"anyDataType"}},"title":"/"},{"id":"29","type":"comment","comment":"Count dividing nuclei","position":{"x":743.6792691921132,"y":55.41607735225023},"width":1980,"height":393,"zIndex":-2002},{"id":"4","type":"numpy.binarize","position":{"x":785.1542292781813,"y":142.26995172010396},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"threshold":{"title":"threshold","value":125,"dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"binarized":{"dataType":"image"}},"title":"binarize"},{"id":"5","type":"Scikiimage.filter.mean","position":{"x":1405.9081026008696,"y":142.49642300891486},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":true,"channelOrder":"channelFirst","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"footprint":{"title":"footprint","value":"None","dataType":"numpy.ndarray"},"out":{"title":"out","value":"None","dataType":"numpy.ndarray"},"mask":{"title":"mask","value":"None","dataType":"numpy.ndarray"},"shift_x":{"title":"shift_x","dataType":"integer"},"shift_y":{"title":"shift_y","dataType":"integer"},"shift_z":{"title":"shift_z","dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"mean"},{"id":"8","type":"image visualization.show_image","position":{"x":2054.8128968042383,"y":139.66218441303647},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":false,"channelOrder":"channelLast","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"title":{"title":"title","dataType":"string"},"cmap":{"title":"cmap","dataType":"string"},"figSize":{"title":"figSize","dataType":"tuple"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"}},"title":"show_image"},{"id":"9","type":"Scikiimage.measure.label","position":{"x":2350.065561730322,"y":138.9757523403137},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"background":{"title":"background","dataType":"anyDataType"},"return_num":{"title":"return_num","dataType":"anyDataType"},"connectivity":{"title":"connectivity","dataType":"anyDataType"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"labels":{"title":"labels","dataType":"numpy.ndarray"},"connectivity":{"title":"connectivity","dataType":"integer"}},"title":"label"},{"id":"31","type":"comment","comment":"smoother image, removing small spurious objects","position":{"x":1074.0513055497013,"y":108.05323909700098},"width":930,"height":311,"zIndex":-1001},{"id":"6","type":"Scikiimage.morphology.disk","position":{"x":1083.6090859878707,"y":141.98100471684342},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"radius":{"title":"radius","value":3,"dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"footprint":{"title":"footprint","dataType":"numpy.ndarray"}},"title":"disk"},{"id":"7","type":"numpy.binarize","position":{"x":1693.2744374216659,"y":141.25366107086967},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"threshold":{"title":"threshold","value":20,"dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"binarized":{"dataType":"image"}},"title":"binarize"},{"id":"11","type":"Scikiimage.segmentation.threshold_multiotsu","position":{"x":812.4413652690191,"y":678.2882792922844},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"classes":{"title":"classes","dataType":"integer"},"nbins":{"title":"nbins","value":0,"dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"thresh":{"title":"thresh","dataType":"list"}},"title":"threshold_multiotsu"},{"id":"12","type":"numpy.binarize","position":{"x":1137.646762120888,"y":676.555590383856},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"threshold":{"title":"threshold","value":128,"dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"binarized":{"dataType":"image"}},"title":"binarize"},{"id":"13","type":"List.Get","position":{"x":811.3218134731819,"y":839.5520361456201},"inputs":{"input":{"title":"list","value":"[]","dataType":"list"},"index":{"title":"index","dataType":"integer"}},"outputs":{"element":{"title":"element","dataType":"anyDataType"}},"dataType":"anyDataType","title":"Get"},{"id":"14","type":"Scikiimage.feature.peak_local_max","position":{"x":1679.298415888473,"y":674.1240484133472},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"ndarray":{"title":"ndarray","dataType":"numpy.ndarray"},"min_distance":{"title":"min_distance","value":"7","dataType":"anyDataType"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"peaks":{"title":"peaks","dataType":"numpy.ndarray"}},"title":"peak_local_max"},{"id":"15","type":"Scikiimage.measure.distance_transform_edt","position":{"x":1316.1320434951265,"y":675.422770992514},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"sampling":{"title":"sampling","dataType":"anyDataType"},"return_distances":{"title":"return_distances","dataType":"boolean"},"return_indices":{"title":"return_indices","dataType":"boolean"},"distances":{"title":"distances","dataType":"anyDataType"},"indices":{"title":"indices","dataType":"anyDataType"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"labels":{"title":"labels","dataType":"numpy.ndarray"},"connectivity":{"title":"connectivity","dataType":"integer"}},"title":"distance_transform_edt"},{"id":"16","type":"Scikiimage.image.create_mask","position":{"x":2017.918779829762,"y":673.3557018360661},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"coordinates":{"title":"coordinates","dataType":"numpy.ndarray"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"create_mask"},{"id":"17","type":"numpy.transpose","position":{"x":1756.7612501069555,"y":811.9883812697949},"inputs":{"ndarray":{"title":"ndarray","dataType":"numpy.ndarray"}},"outputs":{"transpose":{"title":"transpose","dataType":"numpy.ndarray"}},"title":"transpose"},{"id":"18","type":"Scikiimage.measure.label","position":{"x":2243.630279226523,"y":674.816259351513},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"background":{"title":"background","dataType":"anyDataType"},"return_num":{"title":"return_num","dataType":"anyDataType"},"connectivity":{"title":"connectivity","dataType":"anyDataType"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"labels":{"title":"labels","dataType":"numpy.ndarray"},"connectivity":{"title":"connectivity","dataType":"integer"}},"title":"label"},{"id":"19","type":"Scikiimage.segmentation.watershed","position":{"x":2605.1246570983367,"y":673.699303493993},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"markers":{"title":"markers","value":"None","dataType":"numpy.ndarray"},"mask":{"title":"mask","value":"None","dataType":"numpy.ndarray"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"watershed"},{"id":"20","type":"numpy.ndarray * float","position":{"x":1668.7940687622008,"y":552.0085574301407},"inputs":{"input1":{"title":"ndarray","dataType":"numpy.ndarray"},"input2":{"title":"float","value":-1,"dataType":"float"}},"outputs":{"string":{"title":"ndarray","dataType":"numpy.ndarray"}},"title":"*"},{"id":"21","type":"numpy.ndarray To image","position":{"x":2318.589707404476,"y":572.8827026781},"inputs":{"ndarray":{"title":"ndarray","dataType":"numpy.ndarray"}},"outputs":{"image":{"title":"image","dataType":"image"}},"title":"->"},{"id":"22","type":"numpy.image To ndarray","position":{"x":1325.2199996582106,"y":918.1738209962355},"inputs":{"image":{"title":"image","dataType":"image"}},"outputs":{"string":{"title":"ndarray","dataType":"numpy.ndarray"}},"title":"->"},{"id":"23","type":"image visualization.show_image","position":{"x":3136.6504850815036,"y":670.7897088754175},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":false,"channelOrder":"channelLast","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"title":{"title":"title","dataType":"string"},"cmap":{"title":"cmap","dataType":"string"},"figSize":{"title":"figSize","dataType":"tuple"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"}},"title":"show_image"},{"id":"24","type":"Scikiimage.label2rgb","position":{"x":2819.372453438412,"y":671.8658070473082},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"label":{"title":"label","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"image":{"title":"image","dataType":"image"},"alpha":{"title":"alpha","dataType":"float"},"bg_color":{"title":"bg_color","dataType":"string"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"label2rgb"},{"id":"0","type":"Flow Control.Execute Start","position":{"x":-78.3650030221823,"y":313.8385202880937},"outputs":{"execOut":{"dataType":"exec"}},"title":"Execute Start"},{"id":"32","type":"reroute","position":{"x":306.82450082019113,"y":215.97653590485487},"inputs":{"input":{"title":"input","dataType":"image"}},"outputs":{"output":{"title":"output","dataType":"image"}},"dataType":"image","title":"reroute"},{"id":"33","type":"reroute","position":{"x":357.4526405862871,"y":638.3823543729172},"inputs":{"input":{"title":"input","dataType":"image"}},"outputs":{"output":{"title":"output","dataType":"image"}},"dataType":"image","title":"reroute"},{"id":"34","type":"reroute","position":{"x":1012.0958944844551,"y":640.7450267367304},"inputs":{"input":{"title":"input","dataType":"image"}},"outputs":{"output":{"title":"output","dataType":"image"}},"dataType":"image","title":"reroute"},{"id":"35","type":"reroute","position":{"x":1110.6807907082928,"y":274.7472999187809},"inputs":{"input":{"title":"input","dataType":"image"}},"outputs":{"output":{"title":"output","dataType":"image"}},"dataType":"image","title":"reroute"},{"id":"36","type":"reroute","position":{"x":1288.3796841367225,"y":271.9922783152394},"inputs":{"input":{"title":"input","dataType":"image"}},"outputs":{"output":{"title":"output","dataType":"image"}},"dataType":"image","title":"reroute"},{"id":"30","type":"reroute","position":{"x":2052.997842194577,"y":353.2193489224214},"inputs":{"input":{"title":"input","dataType":"image"}},"outputs":{"output":{"title":"output","dataType":"image"}},"dataType":"image","title":"reroute"},{"id":"37","type":"reroute","position":{"x":2266.4833706260933,"y":352.73714666923684},"inputs":{"input":{"title":"input","dataType":"image"}},"outputs":{"output":{"title":"output","dataType":"image"}},"dataType":"image","title":"reroute"},{"id":"38","type":"reroute","position":{"x":2535.048578739529,"y":928.0426901543282},"inputs":{"input":{"title":"input","dataType":"numpy.ndarray"}},"outputs":{"output":{"title":"output","dataType":"numpy.ndarray"}},"dataType":"numpy.ndarray","title":"reroute"},{"id":"39","type":"comment","comment":"Visual Qualitative Analysis","position":{"x":2790.372453438412,"y":639.3658070473082},"width":609.2780316430917,"height":236.42390182810936,"zIndex":-1001},{"id":"40","type":"comment","comment":"mitotic index","position":{"x":3059.4551501568735,"y":365.18756476357726},"width":360,"height":142,"zIndex":-1001},{"id":"41","type":"reroute","position":{"x":673.3437171378552,"y":638.2652322943578},"inputs":{"input":{"title":"input","dataType":"image"}},"outputs":{"output":{"title":"output","dataType":"image"}},"dataType":"image","title":"reroute"},{"id":"42","type":"comment","comment":"Visual Qualitative Analysis","position":{"x":2042.8128968042383,"y":109.66218441303647},"width":257,"height":236,"zIndex":-1001},{"id":"43","type":"comment","comment":"Segment nuclei","position":{"x":327.4526405862871,"y":493.00855743014074},"width":3091,"height":506,"zIndex":-3003},{"id":"44","type":"comment","comment":"The threshold is done by dichotomy, visually and manually","position":{"x":755.1542292781813,"y":112.26995172010396},"width":310,"height":185,"zIndex":-1001},{"id":"45","type":"comment","comment":"label connected regions of an image","position":{"x":2320.065561730322,"y":108.9757523403137},"width":393,"height":235,"zIndex":-1001},{"id":"46","type":"comment","comment":"Create a mask for local max value","position":{"x":1649.298415888473,"y":641.941488273693},"width":564,"height":248,"zIndex":-1001},{"id":"47","type":"comment","comment":"To separate overlapping nuclei, we resort to `sphx_glr_auto_examples_segmentation_plot_watershed.py`.","position":{"x":1630.8590238636684,"y":523.2072288982577},"width":1142,"height":377,"zIndex":-2002},{"id":"48","type":"comment","comment":"auto threshold and get ","position":{"x":781.3218134731819,"y":614.555590383856},"width":505,"height":322,"zIndex":-1001}],"edges":[{"id":"e1-execOut-2-execIn","output":"1","input":"2","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e1-image-2-image","output":"1","input":"2","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"e2-execOut-3-execIn","output":"2","input":"3","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e6-execOut-5-execIn","output":"6","input":"5","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e6-footprint-5-footprint","output":"6","input":"5","outputHandle":"footprint","inputHandle":"footprint","dataType":"numpy.ndarray"},{"id":"e5-execOut-7-execIn","output":"5","input":"7","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e7-binarized-8-image","output":"7","input":"8","outputHandle":"binarized","inputHandle":"image","dataType":"image"},{"id":"e7-execOut-8-execIn","output":"7","input":"8","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e8-execOut-9-execIn","output":"8","input":"9","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e9-labels-10-ndarray","output":"9","input":"10","outputHandle":"labels","inputHandle":"ndarray","dataType":"numpy.ndarray"},{"id":"e3-execOut1-11-execIn","output":"3","input":"11","outputHandle":"execOut1","inputHandle":"execIn","dataType":"exec"},{"id":"e3-execOut0-4-execIn","output":"3","input":"4","outputHandle":"execOut0","inputHandle":"execIn","dataType":"exec"},{"id":"e4-execOut-6-execIn","output":"4","input":"6","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e11-execOut-12-execIn","output":"11","input":"12","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e11-thresh-13-input","output":"11","input":"13","outputHandle":"thresh","inputHandle":"input","dataType":"list"},{"id":"e13-element-12-threshold","output":"13","input":"12","outputHandle":"element","inputHandle":"threshold","dataType":"integer"},{"id":"e12-execOut-15-execIn","output":"12","input":"15","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e12-binarized-15-image","output":"12","input":"15","outputHandle":"binarized","inputHandle":"image","dataType":"image"},{"id":"e15-execOut-14-execIn","output":"15","input":"14","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e15-labels-14-ndarray","output":"15","input":"14","outputHandle":"labels","inputHandle":"ndarray","dataType":"numpy.ndarray"},{"id":"e14-execOut-16-execIn","output":"14","input":"16","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e14-peaks-17-ndarray","output":"14","input":"17","outputHandle":"peaks","inputHandle":"ndarray","dataType":"numpy.ndarray"},{"id":"e17-transpose-16-coordinates","output":"17","input":"16","outputHandle":"transpose","inputHandle":"coordinates","dataType":"numpy.ndarray"},{"id":"e16-execOut-18-execIn","output":"16","input":"18","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e16-image-18-image","output":"16","input":"18","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"e18-execOut-19-execIn","output":"18","input":"19","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e15-labels-20-input1","output":"15","input":"20","outputHandle":"labels","inputHandle":"input1","dataType":"numpy.ndarray"},{"id":"e20-string-21-ndarray","output":"20","input":"21","outputHandle":"string","inputHandle":"ndarray","dataType":"numpy.ndarray"},{"id":"e21-image-19-image","output":"21","input":"19","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"e12-binarized-22-image","output":"12","input":"22","outputHandle":"binarized","inputHandle":"image","dataType":"image"},{"id":"e18-labels-19-markers","output":"18","input":"19","outputHandle":"labels","inputHandle":"markers","dataType":"numpy.ndarray"},{"id":"e19-execOut-24-execIn","output":"19","input":"24","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e19-image-24-label","output":"19","input":"24","outputHandle":"image","inputHandle":"label","dataType":"image"},{"id":"e24-execOut-23-execIn","output":"24","input":"23","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e24-image-23-image","output":"24","input":"23","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"e19-image-25-image","output":"19","input":"25","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"e25-string-26-ndarray","output":"25","input":"26","outputHandle":"string","inputHandle":"ndarray","dataType":"numpy.ndarray"},{"id":"e23-execOut-27-execIn","output":"23","input":"27","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"e10-max-28-int1","output":"10","input":"28","outputHandle":"max","inputHandle":"int1","dataType":"anyDataType"},{"id":"e26-max-28-int2","output":"26","input":"28","outputHandle":"max","inputHandle":"int2","dataType":"anyDataType"},{"id":"e28-quotient-27-input","output":"28","input":"27","outputHandle":"quotient","inputHandle":"input","dataType":"string"},{"id":"reactflow__edge-0execOut-1execIn","output":"0","input":"1","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-1image-32input","output":"1","input":"32","outputHandle":"image","inputHandle":"input","dataType":"image"},{"id":"reactflow__edge-32output-4image","output":"32","input":"4","outputHandle":"output","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-1image-33input","output":"1","input":"33","outputHandle":"image","inputHandle":"input","dataType":"image"},{"id":"reactflow__edge-34output-12image","output":"34","input":"12","outputHandle":"output","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-4binarized-35input","output":"4","input":"35","outputHandle":"binarized","inputHandle":"input","dataType":"image"},{"id":"reactflow__edge-35output-36input","output":"35","input":"36","outputHandle":"output","inputHandle":"input","dataType":"image"},{"id":"reactflow__edge-36output-5image","output":"36","input":"5","outputHandle":"output","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-7binarized-30input","output":"7","input":"30","outputHandle":"binarized","inputHandle":"input","dataType":"image"},{"id":"reactflow__edge-30output-37input","output":"30","input":"37","outputHandle":"output","inputHandle":"input","dataType":"image"},{"id":"reactflow__edge-37output-9image","output":"37","input":"9","outputHandle":"output","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-22string-38input","output":"22","input":"38","outputHandle":"string","inputHandle":"input","dataType":"numpy.ndarray"},{"id":"reactflow__edge-38output-19mask","output":"38","input":"19","outputHandle":"output","inputHandle":"mask","dataType":"numpy.ndarray"},{"id":"reactflow__edge-33output-41input","output":"33","input":"41","outputHandle":"output","inputHandle":"input","dataType":"image"},{"id":"reactflow__edge-41output-34input","output":"41","input":"34","outputHandle":"output","inputHandle":"input","dataType":"image"},{"id":"reactflow__edge-41output-11image","output":"41","input":"11","outputHandle":"output","inputHandle":"image","dataType":"image"}]}
