# %%
{"nodes":[{"id":"2","type":"Function & Variable Creation.Create Function","position":{"x":-164.50354845498396,"y":290.0006839236061},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"new_out_0":{"title":"image","value":{"dataType":"None","value":"None","layout":["bchw"],"colorMode":["rgb"],"intensityRange":"0-255","device":"cpu"},"dataType":"image"}},"nodeRef":"17","title":"sgement_the_nucleus_rim"},{"id":"3","type":"Scikiimage.filter.gaussian","position":{"x":228.446188056393,"y":289.1291848487277},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":true,"channelOrder":"channelFirst","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"sigma":{"title":"sigma","value":1.4,"dataType":"float"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"gaussian"},{"id":"4","type":"Scikiimage.segmentation.threshold_otsu","position":{"x":517.4301221059716,"y":288.4557335928521},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":true,"channelOrder":"channelFirst","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"nbins":{"title":"nbins","dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"threshold":{"title":"threshold","dataType":"float"}},"title":"threshold_otsu"},{"id":"6","type":"reroute","position":{"x":519.6636796581793,"y":429.025232894598},"inputs":{"input":{"title":"input","dataType":"image"}},"outputs":{"output":{"title":"output","dataType":"image"}},"dataType":"image","title":"reroute"},{"id":"7","type":"reroute","position":{"x":729.1710383388089,"y":430.8912988776718},"inputs":{"input":{"title":"input","dataType":"image"}},"outputs":{"output":{"title":"output","dataType":"image"}},"dataType":"image","title":"reroute"},{"id":"8","type":"ndimage.binary_fill_holes","position":{"x":988.5223640384754,"y":287.1495489348092},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":true,"channelOrder":"channelFirst","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"structure":{"title":"structure","dataType":"anyDataType"},"output":{"title":"output","dataType":"anyDataType"},"origin":{"title":"origin","dataType":"integer"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"binary_fill_holes"},{"id":"9","type":"Scikiimage.segmentation.clear_border","position":{"x":1291.9370372161618,"y":286.76843592736327},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":true,"channelOrder":"channelFirst","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"clear_border"},{"id":"10","type":"Scikiimage.morphology.binary_dilation","position":{"x":1474.9767662622535,"y":286.4814355048236},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":true,"channelOrder":"channelFirst","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"footprint":{"title":"footprint","dataType":"anyDataType"},"out":{"title":"out","dataType":"anyDataType"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"dilated_image":{"title":"dilated_image","dataType":"image"}},"title":"binary_dilation"},{"id":"11","type":"Scikiimage.morphology.binary_erosion","position":{"x":1828.30801721741,"y":286.30321314163064},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":true,"channelOrder":"channelFirst","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"footprint":{"title":"footprint","dataType":"anyDataType"},"out":{"title":"out","dataType":"anyDataType"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"eroded_image":{"title":"eroded_image","dataType":"image"}},"title":"binary_erosion"},{"id":"12","type":"Scikiimage.image.subtraction","position":{"x":2183.5174696187623,"y":286.81560785278504},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"subtrahend":{"title":"subtrahend","dataType":"image"},"minuend":{"title":"minuend","dataType":"image"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"subtraction"},{"id":"13","type":"reroute","position":{"x":1462.2082782407008,"y":461.08612408795705},"inputs":{"input":{"title":"input","dataType":"image"}},"outputs":{"output":{"title":"output","dataType":"image"}},"dataType":"image","title":"reroute"},{"id":"14","type":"reroute","position":{"x":2090.852791704015,"y":457.3874272100478},"inputs":{"input":{"title":"input","dataType":"image"}},"outputs":{"output":{"title":"output","dataType":"image"}},"dataType":"image","title":"reroute"},{"id":"0","type":"Flow Control.Execute Start","position":{"x":-265.51761736002265,"y":1089.349353229621},"outputs":{"execOut":{"dataType":"exec"}},"title":"Execute Start"},{"id":"1","type":"imageio.read_image","position":{"x":29.17458421285062,"y":909.3256761444803},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"path":{"title":"path","value":"channel_0.jpg","dataType":"string"},"mode":{"title":"mode","value":" ImageReadMode.GRAY","dataType":"imageio.ImageReadMode"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"read_image"},{"id":"16","type":"Function & Variable Creation.functionCall","position":{"x":309.2532759783652,"y":908.8720915403109},"inputs":{"execOut":{"title":"execOut","dataType":"exec"},"new_out_0":{"title":"image","dataType":"image"}},"outputs":{"functionCallExecOut":{"title":"functionCallExecOut","dataType":"exec"},"new_in_0":{"title":"mask","value":{"dataType":"None","value":"None","layout":["bchw"],"colorMode":["rgb"],"intensityRange":"0-255","device":"cpu"},"dataType":"image"}},"nodeRef":"2","title":"sgement_the_nucleus_rim"},{"id":"17","type":"Function & Variable Creation.Return","position":{"x":2394.8703735674276,"y":285.62855329263084},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"new_in_0":{"title":"mask","value":{"dataType":"None","value":"None","layout":["bchw"],"colorMode":["rgb"],"intensityRange":"0-255","device":"cpu"},"dataType":"image"}},"title":"Return"},{"id":"15","type":"imageio.read_image","position":{"x":32.41263100545871,"y":1115.3322926047636},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"path":{"title":"path","value":"channel_1.jpg","dataType":"string"},"mode":{"title":"mode","value":" ImageReadMode.GRAY","dataType":"imageio.ImageReadMode"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"read_image"},{"id":"18","type":"Scikiimage.image.mask_image","position":{"x":320.51517471160565,"y":1116.1914456745455},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"rgb","isMiniBatched":true,"channelOrder":"channelFirst","intensityRange":"0-255"},{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"mask":{"title":"mask","dataType":"numpy.ndarray"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"image":{"title":"image","dataType":"image"}},"title":"mask_image"},{"id":"19","type":"numpy.image To ndarray","position":{"x":310.82187826379584,"y":1016.977781355976},"inputs":{"image":{"title":"image","dataType":"image"}},"outputs":{"string":{"title":"ndarray","dataType":"numpy.ndarray"}},"title":"->"},{"id":"20","type":"Scikiimage.measure.regionprops_table","position":{"x":297.5313453824556,"y":1332.875611043721},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"label_image":{"title":"label_image","dataType":"numpy.ndarray"},"intensity_image":{"title":"sampling","value":"None","dataType":"anyDataType"},"properties":{"title":"properties","value":"('label', 'area', 'intensity_mean')","dataType":"tuple"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"labels":{"title":"labels","dataType":"numpy.ndarray"},"connectivity":{"title":"connectivity","dataType":"integer"}},"title":"regionprops_table"},{"id":"22","type":"file.save_to_csv","position":{"x":644.7640010520756,"y":1333.7326737170129},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"path":{"title":"path","dataType":"string"},"pandas.dataframe":{"title":"pandas dataframe","value":"","dataType":"anyDataType"},"sep":{"title":"sep","value":"'\\t'","dataType":"string"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"}},"title":"save_to_csv"},{"id":"23","type":"Flow Control.Sequence","position":{"x":-146.35652440866033,"y":1090.0745152908607},"inputs":{"execIn":{"title":"execIn","dataType":"exec"}},"outputs":{"execOut0":{"title":"Then 0","dataType":"exec"},"execOut1":{"title":"Then 1","dataType":"exec"},"execOut-0":{"title":"Then 2","dataType":"exec"}},"title":"Sequence"},{"id":"21","type":"Function & Variable Creation.Create Variable","position":{"x":537.3820433366186,"y":909.1566210119039},"inputs":{"execIn":{"dataType":"exec"},"name":{"title":"name","value":"mask","dataType":"string"},"type":{"title":"type","value":"numpy.ndarray","dataType":"DataType"},"value":{"title":"value","value":"false","dataType":"numpy.ndarray"}},"outputs":{"execOut":{"dataType":"exec"}},"title":"New Variable"},{"id":"24","type":"Function & Variable Creation.Getter","position":{"x":217.5101142281472,"y":1249.0653438695356},"outputs":{"getter":{"title":"mask","dataType":"numpy.ndarray"}},"nodeRef":"21"},{"id":"25","type":"Function & Variable Creation.Getter","position":{"x":44.27590468254755,"y":1485.8211727864114},"outputs":{"getter":{"title":"mask","dataType":"numpy.ndarray"}},"nodeRef":"21"},{"id":"26","type":"numpy.astype","position":{"x":40.386174763747874,"y":1410.2334421318906},"inputs":{"ndarray":{"title":"ndarray","dataType":"numpy.ndarray"},"type":{"title":"type","dataType":"numpy.numpytype"}},"outputs":{"ndarray2":{"title":"ndarray","dataType":"numpy.ndarray"}},"title":"->"},{"id":"27","type":"Function & Variable Creation.Create Variable","position":{"x":541.4922586031971,"y":1115.9484845595648},"inputs":{"execIn":{"dataType":"exec"},"name":{"title":"name","value":"masked","dataType":"string"},"type":{"title":"type","value":"image","dataType":"DataType"},"value":{"title":"value","value":"false","dataType":"image"}},"outputs":{"execOut":{"dataType":"exec"}},"title":"New Variable"},{"id":"28","type":"Function & Variable Creation.Getter","position":{"x":169.57659101957944,"y":1485.064877317163},"outputs":{"getter":{"title":"masked","value":{"dataType":"None","value":"None","layout":["bchw"],"colorMode":["rgb"],"intensityRange":"0-255","device":"cpu"},"dataType":"image"}},"nodeRef":"27"},{"id":"29","type":"comment","comment":"save propertie: label, area, intensity_mean to csv","position":{"x":15.926324623799928,"y":1296.8666077339392},"width":870,"height":218,"zIndex":-1001},{"id":"30","type":"reroute","position":{"x":31.809159769658436,"y":1375.7973461182844},"inputs":{"input":{"title":"input","dataType":"exec"}},"outputs":{"output":{"title":"output","dataType":"exec"}},"dataType":"exec","title":"reroute"},{"id":"31","type":"comment","comment":"create the mask based on the channel 0 image","position":{"x":16.253275978365195,"y":875.8720915403109},"width":774,"height":202,"zIndex":-1001},{"id":"32","type":"comment","position":{"x":17.033174139870937,"y":1083.0775779926566},"width":788,"height":200,"zIndex":-1001},{"id":"33","type":"numpy.binarize_normalized","position":{"x":823.1621237359134,"y":288.48668890382436},"inputs":{"execIn":{"title":"execIn","dataType":"exec"},"image":{"title":"image","value":{"dataType":"numpy.ndarray","metadata":[{"colorChannel":"grayscale","isMiniBatched":false,"channelOrder":"none","intensityRange":"0-255"}]},"dataType":"image"},"threshold":{"title":"threshold","value":0.5,"dataType":"float"}},"outputs":{"execOut":{"title":"execOut","dataType":"exec"},"binarized":{"dataType":"image"}},"title":"binarize_normalized"}],"edges":[{"id":"reactflow__edge-2execOut-3execIn","output":"2","input":"3","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-2new_out_0-3image","output":"2","input":"3","outputHandle":"new_out_0","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-3execOut-4execIn","output":"3","input":"4","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-3image-4image","output":"3","input":"4","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-3image-6input","output":"3","input":"6","outputHandle":"image","inputHandle":"input","dataType":"image"},{"id":"reactflow__edge-6output-7input","output":"6","input":"7","outputHandle":"output","inputHandle":"input","dataType":"image"},{"id":"reactflow__edge-8execOut-9execIn","output":"8","input":"9","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-8image-9image","output":"8","input":"9","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-9execOut-10execIn","output":"9","input":"10","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-9image-10image","output":"9","input":"10","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-10execOut-11execIn","output":"10","input":"11","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-10dilated_image-11image","output":"10","input":"11","outputHandle":"dilated_image","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-11execOut-12execIn","output":"11","input":"12","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-11eroded_image-12minuend","output":"11","input":"12","outputHandle":"eroded_image","inputHandle":"minuend","dataType":"image"},{"id":"reactflow__edge-9image-13input","output":"9","input":"13","outputHandle":"image","inputHandle":"input","dataType":"image"},{"id":"reactflow__edge-13output-14input","output":"13","input":"14","outputHandle":"output","inputHandle":"input","dataType":"image"},{"id":"reactflow__edge-14output-12subtrahend","output":"14","input":"12","outputHandle":"output","inputHandle":"subtrahend","dataType":"image"},{"id":"reactflow__edge-1execOut-16execOut","output":"1","input":"16","outputHandle":"execOut","inputHandle":"execOut","dataType":"exec"},{"id":"reactflow__edge-1image-16new_out_0","output":"1","input":"16","outputHandle":"image","inputHandle":"new_out_0","dataType":"image"},{"id":"reactflow__edge-12execOut-17execIn","output":"12","input":"17","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-12image-17new_in_0","output":"12","input":"17","outputHandle":"image","inputHandle":"new_in_0","dataType":"image"},{"id":"reactflow__edge-15execOut-18execIn","output":"15","input":"18","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-15image-18image","output":"15","input":"18","outputHandle":"image","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-16new_in_0-19image","output":"16","input":"19","outputHandle":"new_in_0","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-20execOut-22execIn","output":"20","input":"22","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-20labels-22pandas.dataframe","output":"20","input":"22","outputHandle":"labels","inputHandle":"pandas.dataframe","dataType":"anyDataType"},{"id":"reactflow__edge-0execOut-23execIn","output":"0","input":"23","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-16functionCallExecOut-21execIn","output":"16","input":"21","outputHandle":"functionCallExecOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-19string-21value","output":"19","input":"21","outputHandle":"string","inputHandle":"value","dataType":"numpy.ndarray"},{"id":"reactflow__edge-24getter-18mask","output":"24","input":"18","outputHandle":"getter","inputHandle":"mask","dataType":"numpy.ndarray"},{"id":"reactflow__edge-25getter-26ndarray","output":"25","input":"26","outputHandle":"getter","inputHandle":"ndarray","dataType":"numpy.ndarray"},{"id":"reactflow__edge-26ndarray2-20label_image","output":"26","input":"20","outputHandle":"ndarray2","inputHandle":"label_image","dataType":"numpy.ndarray"},{"id":"reactflow__edge-18execOut-27execIn","output":"18","input":"27","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-18image-27value","output":"18","input":"27","outputHandle":"image","inputHandle":"value","dataType":"image"},{"id":"reactflow__edge-28getter-20intensity_image","output":"28","input":"20","outputHandle":"getter","inputHandle":"intensity_image","dataType":"anyDataType"},{"id":"reactflow__edge-23execOut-0-30input","output":"23","input":"30","outputHandle":"execOut-0","inputHandle":"input","dataType":"exec"},{"id":"reactflow__edge-30output-20execIn","output":"30","input":"20","outputHandle":"output","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-23execOut1-15execIn","output":"23","input":"15","outputHandle":"execOut1","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-23execOut0-1execIn","output":"23","input":"1","outputHandle":"execOut0","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-4execOut-33execIn","output":"4","input":"33","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-33execOut-8execIn","output":"33","input":"8","outputHandle":"execOut","inputHandle":"execIn","dataType":"exec"},{"id":"reactflow__edge-33binarized-8image","output":"33","input":"8","outputHandle":"binarized","inputHandle":"image","dataType":"image"},{"id":"reactflow__edge-4threshold-33threshold","output":"4","input":"33","outputHandle":"threshold","inputHandle":"threshold","dataType":"float"},{"id":"reactflow__edge-7output-33image","output":"7","input":"33","outputHandle":"output","inputHandle":"image","dataType":"image"}]}
